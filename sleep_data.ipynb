# %% [markdown]
# <a href="https://colab.research.google.com/github/nalyzhang/MO/blob/main/sleep_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv('/content/sample_data/ah_sleep.csv')
df.head(3)
# Out:
#                                                   id   timestamp  \
# 0  applehealth_sleep_2261472_58c9063982329c8111fd...  1715115443
# 1  applehealth_sleep_2261472_a547bfb3709c8af9b90b...  1730481861
# 2  applehealth_sleep_2261472_e3ec8989eb733107ab6b...  1727954727
#
#    data_version          data_type  \
# 0             2  applehealth_sleep
# 1             2  applehealth_sleep
# 2             2  applehealth_sleep
#
#                                                 data     provider  user_id
# 0  [{"dataType":"category","entryType":"sleep","h...  applehealth  2261472
# 1  [{"dataType":"category","entryType":"sleep","h...  applehealth  2261472
# 2  [{"dataType":"category","entryType":"sleep","h...  applehealth  2261472

# %%
import json


def flatten_dict(d, prefix=''):
    items = {}
    for key, value in d.items():
        new_key = f"{prefix}{key}" if prefix == '' else f"{prefix}.{key}"
        if isinstance(value, dict):
            items.update(flatten_dict(value, new_key))
        else:
            items[new_key] = value
    return items


df['data'] = df['data'].apply(json.loads)

data_list=[]
for index, row in df.iterrows():
    data_list.append(flatten_dict(row['data'][0]))

data_df = pd.DataFrame(data_list)
data_df.head()
# Out:
#    dataType entryType                         health_kit_id  \
# 0  category     sleep  ABCD13F9-CAB2-42E8-BEFB-63C855FC3307
# 1  category     sleep  4CDBEAB5-8229-452C-831E-3436152F94CA
# 2  category     sleep  BAE77E9A-1490-4901-B42D-E6026AB0E97B
# 3  category     sleep  BCCD626F-CD18-42A7-8BB5-D1675EB1CE74
# 4  category     sleep  101079AB-EC9E-483C-9429-6762D23A4271
#
#   metadata.HKTimeZone                        sourceData.bundleIdentifier  \
# 0       Europe/Vienna  com.apple.health.285A5E5B-B5D6-4182-BC34-9A821...
# 1                 NaN                            com.tantsissa.AutoSleep
# 2                 NaN                            com.tantsissa.AutoSleep
# 3                 NaN                            com.tantsissa.AutoSleep
# 4    Europe/Podgorica  com.apple.health.285A5E5B-B5D6-4182-BC34-9A821...
#
#   sourceData.operatingSystemVersion sourceData.productType  \
# 0                            17.4.1             iPhone15,2
# 1                            18.0.0             iPhone15,2
# 2                            18.0.0             iPhone15,2
# 3                            17.5.1             iPhone15,2
# 4                            17.3.0             iPhone15,2
#
#   sourceData.sourceName sourceData.version sourceGroup  ...  \
# 0        iPhone Аннушка             17.4.1   HealthKit  ...
# 1             AutoSleep            6.11.21   HealthKit  ...
# 2             AutoSleep            6.10.30   HealthKit  ...
# 3             AutoSleep            6.10.30   HealthKit  ...
# 4        iPhone Аннушка               17.3   HealthKit  ...
#
#   metadata.stagesAwake metadata.stagesDeep metadata.stagesLight  \
# 0                  NaN                 NaN                  NaN
# 1                870.0              2670.0              18750.0
# 2               5340.0              1500.0              15510.0
# 3               2010.0              2250.0              23760.0
# 4                  NaN                 NaN                  NaN
#
#   metadata.stagesREM metadata.stagesSleep  metadata.usingStages  \
# 0                NaN                  NaN                   NaN
# 1             3600.0              25020.0                   Yes
# 2             4500.0              21510.0                   NaN
# 3             4140.0              30150.0                   NaN
# 4                NaN                  NaN                   NaN
#
#   metadata.HKExternalUUID metadata.HKMetadataKeySyncIdentifier  \
# 0                     NaN                                  NaN
# 1                     NaN                                  NaN
# 2                     NaN                                  NaN
# 3                     NaN                                  NaN
# 4                     NaN                                  NaN
#
#   metadata.HKMetadataKeySyncVersion metadata.HKWasUserEntered
# 0                               NaN                       NaN
# 1                               NaN                       NaN
# 2                               NaN                       NaN
# 3                               NaN                       NaN
# 4                               NaN                       NaN
#
# [5 rows x 39 columns]
